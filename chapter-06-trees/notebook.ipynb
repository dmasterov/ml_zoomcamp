# %% [markdown]
# 6. Decision Trees and Ensemble Learning

# %% [markdown]
# 6.1 Credit risk scoring project

# %%
import pandas as pd
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data = 'https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-06-trees/CreditScoring.csv'

# %%
# !wget $data
# Out:
# --2025-08-14 13:35:50--  https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-06-trees/CreditScoring.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8002::154, 2606:50c0:8003::154, 2606:50c0:8001::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8002::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 182489 (178K) [text/plain]
# Saving to: ‘CreditScoring.csv’
#
# CreditScoring.csv   100%[===================>] 178,21K  --.-KB/s    in 0,08s
#
# 2025-08-14 13:35:51 (2,26 MB/s) - ‘CreditScoring.csv’ saved [182489/182489]

# %%
# !head CreditScoring.csv
# Out:
# "Status","Seniority","Home","Time","Age","Marital","Records","Job","Expenses","Income","Assets","Debt","Amount","Price"
# 1,9,1,60,30,2,1,3,73,129,0,0,800,846
# 1,17,1,60,58,3,1,1,48,131,0,0,1000,1658
# 2,10,2,36,46,2,2,3,90,200,3000,0,2000,2985
# 1,0,1,60,24,1,1,1,63,182,2500,0,900,1325
# 1,0,1,36,26,1,1,1,46,107,0,0,310,910
# 1,1,2,60,36,2,1,1,75,214,3500,0,650,1645
# 1,29,2,60,44,2,1,1,75,125,10000,0,1600,1800
# 1,9,5,12,27,1,1,1,35,80,0,0,200,1093
# 1,0,2,60,32,2,1,3,90,107,15000,0,1200,1957

# %%
df = pd.read_csv(data)

# %%
df.head()
# Out:
#    Status  Seniority  Home  Time  Age  Marital  Records  Job  Expenses  \
# 0       1          9     1    60   30        2        1    3        73
# 1       1         17     1    60   58        3        1    1        48
# 2       2         10     2    36   46        2        2    3        90
# 3       1          0     1    60   24        1        1    1        63
# 4       1          0     1    36   26        1        1    1        46
#
#    Income  Assets  Debt  Amount  Price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
df.columns = df.columns.str.lower()

# %%
df.status.value_counts()
# Out:
# status
# 1    3200
# 2    1254
# 0       1
# Name: count, dtype: int64

# %%
status_values = {
    1: 'ok',
    2: 'default',
    0: 'unk'
}

df.status = df.status.map(status_values)

# %%
home_values = {
    1: 'rent',
    2: 'owner',
    3: 'private',
    4: 'ignore',
    5: 'parents',
    6: 'other',
    0: 'unk'
}

df.home = df.home.map(home_values)

marital_values = {
    1: 'single',
    2: 'married',
    3: 'widow',
    4: 'separated',
    5: 'divorced',
    0: 'unk'
}

df.marital = df.marital.map(marital_values)

records_values = {
    1: 'no',
    2: 'yes',
    0: 'unk'
}

df.records = df.records.map(records_values)

job_values = {
    1: 'fixed',
    2: 'partime',
    3: 'freelance',
    4: 'others',
    0: 'unk'
}

df.job = df.job.map(job_values)

# %%
df.head()
# Out:
#     status  seniority   home  time  age  marital records        job  expenses  \
# 0       ok          9   rent    60   30  married      no  freelance        73
# 1       ok         17   rent    60   58    widow      no      fixed        48
# 2  default         10  owner    36   46  married     yes  freelance        90
# 3       ok          0   rent    60   24   single      no      fixed        63
# 4       ok          0   rent    36   26   single      no      fixed        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
for c in ['income', 'assets', 'debt']:
    df[c] = df[c].replace(to_replace=99999999, value=np.nan)

# %%
df.describe().round()
# Out:
#        seniority    time     age  expenses  income    assets     debt  amount  \
# count     4455.0  4455.0  4455.0    4455.0  4421.0    4408.0   4437.0  4455.0
# mean         8.0    46.0    37.0      56.0   131.0    5403.0    343.0  1039.0
# std          8.0    15.0    11.0      20.0    86.0   11573.0   1246.0   475.0
# min          0.0     6.0    18.0      35.0     0.0       0.0      0.0   100.0
# 25%          2.0    36.0    28.0      35.0    80.0       0.0      0.0   700.0
# 50%          5.0    48.0    36.0      51.0   120.0    3000.0      0.0  1000.0
# 75%         12.0    60.0    45.0      72.0   165.0    6000.0      0.0  1300.0
# max         48.0    72.0    68.0     180.0   959.0  300000.0  30000.0  5000.0
#
#          price
# count   4455.0
# mean    1463.0
# std      628.0
# min      105.0
# 25%     1118.0
# 50%     1400.0
# 75%     1692.0
# max    11140.0

# %%
df = df[df.status != 'unk'].reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split

df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=11)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=11)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = (df_train.status == 'default').astype('int').values
y_val = (df_val.status == 'default').astype('int').values
y_test = (df_test.status == 'default').astype('int').values

# %%
del df_train['status']
del df_val['status']
del df_test['status']

# %%
df_train
# Out:
#       seniority     home  time  age  marital records        job  expenses  \
# 0            10    owner    36   36  married      no  freelance        75
# 1             6  parents    48   32   single     yes      fixed        35
# 2             1  parents    48   40  married      no      fixed        75
# 3             1  parents    48   23   single      no    partime        35
# 4             5    owner    36   46  married      no  freelance        60
# ...         ...      ...   ...  ...      ...     ...        ...       ...
# 2667         18  private    36   45  married      no      fixed        45
# 2668          7  private    60   29  married      no      fixed        60
# 2669          1  parents    24   19   single      no      fixed        35
# 2670         15    owner    48   43  married      no  freelance        60
# 2671         12    owner    48   27  married     yes      fixed        45
#
#       income   assets    debt  amount  price
# 0        0.0  10000.0     0.0    1000   1400
# 1       85.0      0.0     0.0    1100   1330
# 2      121.0      0.0     0.0    1320   1600
# 3       72.0      0.0     0.0    1078   1079
# 4      100.0   4000.0     0.0    1100   1897
# ...      ...      ...     ...     ...    ...
# 2667   220.0  20000.0     0.0     800   1600
# 2668    51.0   3500.0   500.0    1000   1290
# 2669    28.0      0.0     0.0     400    600
# 2670   100.0  18000.0     0.0    2500   2976
# 2671   110.0   5000.0  1300.0     450   1636
#
# [2672 rows x 13 columns]

# %% [markdown]
# 6.3 Decision trees

# %%
def assess_risk(client):
    if client['records'] == 'yes':
        if client['job'] == 'parttime':
            return 'default'
        else:
            return 'ok'
    else:
        if client['assets'] > 6000:
            return 'ok'
        else:
            return 'default'

# %%
xi = df_train.iloc[0].to_dict()

# %%
assess_risk(xi)
# Out:
# 'ok'

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import roc_auc_score
from sklearn.tree import export_text

# %%
train_dicts = df_train.fillna(0).to_dict(orient='records')

# %%
train_dicts
# Out:
# [{'seniority': 10,
#   'home': 'owner',
#   'time': 36,
#   'age': 36,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 75,
#   'income': 0.0,
#   'assets': 10000.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1400},
#  {'seniority': 6,
#   'home': 'parents',
#   'time': 48,
#   'age': 32,
#   'marital': 'single',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 85.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1100,
#   'price': 1330},
#  {'seniority': 1,
#   'home': 'parents',
#   'time': 48,
#   'age': 40,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 121.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1320,
#   'price': 1600},
#  {'seniority': 1,
#   'home': 'parents',
#   'time': 48,
#   'age': 23,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 35,
#   'income': 72.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1078,
#   'price': 1079},
#  {'seniority': 5,
#   'home': 'owner',
#   'time': 36,
#   'age': 46,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 60,
#   'income': 100.0,
#   'assets': 4000.0,
#   'debt': 0.0,
#   'amount': 1100,
#   'price': 1897},
#  {'seniority': 0,
#   'home': 'parents',
#   'time': 48,
#   'age': 28,
#   'marital': 'divorced',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 280.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1300,
#   'price': 2058},
#  {'seniority': 3,
#   'home': 'parents',
#   'time': 60,
#   'age': 24,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 100.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1500,
#   'price': 2100},
#  {'seniority': 1,
#   'home': 'rent',
#   'time': 60,
#   'age': 33,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 85,
#   'income': 250.0,
#   'assets': 5000.0,
#   'debt': 0.0,
#   'amount': 1700,
#   'price': 1878},
#  {'seniority': 0,
#   'home': 'owner',
#   'time': 60,
#   'age': 36,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 90,
#   'income': 113.0,
#   'assets': 4000.0,
#   'debt': 198.0,
#   'amount': 400,
#   'price': 790},
#  {'seniority': 1,
#   'home': 'owner',
#   'time': 24,
#   'age': 32,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 45,
#   'income': 182.0,
#   'assets': 4000.0,
#   'debt': 200.0,
#   'amount': 175,
#   'price': 175},
#  {'seniority': 1,
#   'home': 'owner',
#   'time': 48,
#   'age': 39,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'freelance',
#   'expenses': 60,
#   'income': 0.0,
#   'assets': 6000.0,
#   'debt': 0.0,
#   'amount': 1300,
#   'price': 3626},
#  {'seniority': 15,
#   'home': 'rent',
#   'time': 48,
#   'age': 40,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 57,
#   'income': 120.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1500},
#  {'seniority': 6,
#   'home': 'owner',
#   'time': 60,
#   'age': 29,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 125.0,
#   'assets': 5000.0,
#   'debt': 0.0,
#   'amount': 1500,
#   'price': 1531},
#  {'seniority': 2,
#   'home': 'owner',
#   'time': 36,
#   'age': 27,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 156.0,
#   'assets': 6000.0,
#   'debt': 0.0,
#   'amount': 700,
#   'price': 1045},
#  {'seniority': 1,
#   'home': 'parents',
#   'time': 48,
#   'age': 23,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 65.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 400,
#   'price': 1195},
#  {'seniority': 3,
#   'home': 'private',
#   'time': 60,
#   'age': 27,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 194.0,
#   'assets': 3500.0,
#   'debt': 1000.0,
#   'amount': 700,
#   'price': 1083},
#  {'seniority': 16,
#   'home': 'parents',
#   'time': 48,
#   'age': 35,
#   'marital': 'separated',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 103.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 500,
#   'price': 862},
#  {'seniority': 22,
#   'home': 'owner',
#   'time': 48,
#   'age': 40,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 180.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1200,
#   'price': 2206},
#  {'seniority': 6,
#   'home': 'parents',
#   'time': 60,
#   'age': 38,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 75.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1175,
#   'price': 1800},
#  {'seniority': 16,
#   'home': 'parents',
#   'time': 60,
#   'age': 31,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 160.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1400,
#   'price': 1850},
#  {'seniority': 2,
#   'home': 'rent',
#   'time': 36,
#   'age': 36,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 95,
#   'income': 200.0,
#   'assets': 5000.0,
#   'debt': 0.0,
#   'amount': 800,
#   'price': 1158},
#  {'seniority': 2,
#   'home': 'owner',
#   'time': 60,
#   'age': 38,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 88.0,
#   'assets': 3500.0,
#   'debt': 500.0,
#   'amount': 1100,
#   'price': 1263},
#  {'seniority': 2,
#   'home': 'parents',
#   'time': 60,
#   'age': 25,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 110.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 860,
#   'price': 959},
#  {'seniority': 18,
#   'home': 'owner',
#   'time': 48,
#   'age': 32,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 71.0,
#   'assets': 4000.0,
#   'debt': 39.0,
#   'amount': 660,
#   'price': 1461},
#  {'seniority': 10,
#   'home': 'rent',
#   'time': 36,
#   'age': 45,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 83,
#   'income': 383.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 800,
#   'price': 4300},
#  {'seniority': 0,
#   'home': 'owner',
#   'time': 24,
#   'age': 30,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 60,
#   'income': 76.0,
#   'assets': 4500.0,
#   'debt': 0.0,
#   'amount': 400,
#   'price': 450},
#  {'seniority': 18,
#   'home': 'rent',
#   'time': 48,
#   'age': 53,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 54,
#   'income': 92.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1340,
#   'price': 1345},
#  {'seniority': 10,
#   'home': 'rent',
#   'time': 60,
#   'age': 42,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 76,
#   'income': 158.0,
#   'assets': 5000.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1000},
#  {'seniority': 5,
#   'home': 'rent',
#   'time': 48,
#   'age': 31,
#   'marital': 'single',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 47,
#   'income': 120.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 900,
#   'price': 1492},
#  {'seniority': 2,
#   'home': 'owner',
#   'time': 36,
#   'age': 37,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 125.0,
#   'assets': 2000.0,
#   'debt': 0.0,
#   'amount': 450,
#   'price': 1490},
#  {'seniority': 23,
#   'home': 'rent',
#   'time': 48,
#   'age': 57,
#   'marital': 'single',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 49,
#   'income': 142.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1300,
#   'price': 1450},
#  {'seniority': 15,
#   'home': 'owner',
#   'time': 48,
#   'age': 53,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 75,
#   'income': 100.0,
#   'assets': 17000.0,
#   'debt': 0.0,
#   'amount': 500,
#   'price': 1114},
#  {'seniority': 1,
#   'home': 'other',
#   'time': 36,
#   'age': 37,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 60,
#   'income': 27.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 850,
#   'price': 1000},
#  {'seniority': 19,
#   'home': 'owner',
#   'time': 60,
#   'age': 49,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 135,
#   'income': 150.0,
#   'assets': 3500.0,
#   'debt': 0.0,
#   'amount': 1100,
#   'price': 1477},
#  {'seniority': 23,
#   'home': 'other',
#   'time': 60,
#   'age': 43,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 155.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1650,
#   'price': 2270},
#  {'seniority': 2,
#   'home': 'owner',
#   'time': 36,
#   'age': 30,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 350.0,
#   'assets': 4000.0,
#   'debt': 0.0,
#   'amount': 800,
#   'price': 1800},
#  {'seniority': 2,
#   'home': 'rent',
#   'time': 60,
#   'age': 42,
#   'marital': 'single',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 0.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1900,
#   'price': 2259},
#  {'seniority': 1,
#   'home': 'rent',
#   'time': 48,
#   'age': 37,
#   'marital': 'separated',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 46,
#   'income': 110.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 900,
#   'price': 1312},
#  {'seniority': 3,
#   'home': 'owner',
#   'time': 60,
#   'age': 38,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 75,
#   'income': 90.0,
#   'assets': 3000.0,
#   'debt': 0.0,
#   'amount': 930,
#   'price': 1135},
#  {'seniority': 15,
#   'home': 'owner',
#   'time': 24,
#   'age': 29,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 130.0,
#   'assets': 4000.0,
#   'debt': 0.0,
#   'amount': 400,
#   'price': 899},
#  {'seniority': 24,
#   'home': 'other',
#   'time': 60,
#   'age': 41,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'freelance',
#   'expenses': 75,
#   'income': 0.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 2200,
#   'price': 2428},
#  {'seniority': 6,
#   'home': 'parents',
#   'time': 60,
#   'age': 29,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 35,
#   'income': 0.0,
#   'assets': 3500.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1183},
#  {'seniority': 1,
#   'home': 'parents',
#   'time': 48,
#   'age': 36,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 60,
#   'income': 150.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1148},
#  {'seniority': 13,
#   'home': 'private',
#   'time': 24,
#   'age': 59,
#   'marital': 'widow',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 87.0,
#   'assets': 1200.0,
#   'debt': 0.0,
#   'amount': 425,
#   'price': 750},
#  {'seniority': 6,
#   'home': 'other',
#   'time': 48,
#   'age': 25,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 300.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 2400,
#   'price': 2700},
#  {'seniority': 16,
#   'home': 'private',
#   'time': 48,
#   'age': 34,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 85.0,
#   'assets': 2000.0,
#   'debt': 0.0,
#   'amount': 800,
#   'price': 1866},
#  {'seniority': 6,
#   'home': 'parents',
#   'time': 12,
#   'age': 23,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 100.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 475,
#   'price': 1080},
#  {'seniority': 6,
#   'home': 'rent',
#   'time': 60,
#   'age': 41,
#   'marital': 'divorced',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 55,
#   'income': 97.0,
#   'assets': 7000.0,
#   'debt': 5000.0,
#   'amount': 1900,
#   'price': 2260},
#  {'seniority': 3,
#   'home': 'owner',
#   'time': 36,
#   'age': 28,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 35,
#   'income': 180.0,
#   'assets': 5000.0,
#   'debt': 0.0,
#   'amount': 375,
#   'price': 1139},
#  {'seniority': 6,
#   'home': 'owner',
#   'time': 36,
#   'age': 49,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 60,
#   'income': 100.0,
#   'assets': 22000.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1790},
#  {'seniority': 9,
#   'home': 'owner',
#   'time': 60,
#   'age': 24,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 125.0,
#   'assets': 4000.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1174},
#  {'seniority': 1,
#   'home': 'private',
#   'time': 48,
#   'age': 36,
#   'marital': 'single',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 173.0,
#   'assets': 7700.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 2008},
#  {'seniority': 20,
#   'home': 'owner',
#   'time': 60,
#   'age': 47,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 90,
#   'income': 212.0,
#   'assets': 11000.0,
#   'debt': 0.0,
#   'amount': 1150,
#   'price': 1669},
#  {'seniority': 14,
#   'home': 'owner',
#   'time': 48,
#   'age': 53,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 95.0,
#   'assets': 3000.0,
#   'debt': 0.0,
#   'amount': 1060,
#   'price': 1060},
#  {'seniority': 3,
#   'home': 'owner',
#   'time': 36,
#   'age': 37,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 55.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1500,
#   'price': 2315},
#  {'seniority': 0,
#   'home': 'owner',
#   'time': 60,
#   'age': 61,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'others',
#   'expenses': 35,
#   'income': 113.0,
#   'assets': 3000.0,
#   'debt': 0.0,
#   'amount': 1300,
#   'price': 1726},
#  {'seniority': 20,
#   'home': 'owner',
#   'time': 60,
#   'age': 51,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 250.0,
#   'assets': 2500.0,
#   'debt': 0.0,
#   'amount': 1250,
#   'price': 1825},
#  {'seniority': 0,
#   'home': 'other',
#   'time': 60,
#   'age': 31,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 35,
#   'income': 128.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 900,
#   'price': 982},
#  {'seniority': 16,
#   'home': 'parents',
#   'time': 60,
#   'age': 35,
#   'marital': 'separated',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 105.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 800,
#   'price': 1084},
#  {'seniority': 4,
#   'home': 'rent',
#   'time': 60,
#   'age': 33,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 82,
#   'income': 69.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 2000,
#   'price': 2216},
#  {'seniority': 13,
#   'home': 'private',
#   'time': 48,
#   'age': 36,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 81.0,
#   'assets': 4750.0,
#   'debt': 0.0,
#   'amount': 1200,
#   'price': 1385},
#  {'seniority': 14,
#   'home': 'owner',
#   'time': 60,
#   'age': 47,
#   'marital': 'widow',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 100.0,
#   'assets': 4000.0,
#   'debt': 2000.0,
#   'amount': 1475,
#   'price': 1475},
#  {'seniority': 7,
#   'home': 'owner',
#   'time': 60,
#   'age': 55,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 124.0,
#   'assets': 5000.0,
#   'debt': 0.0,
#   'amount': 800,
#   'price': 982},
#  {'seniority': 3,
#   'home': 'owner',
#   'time': 48,
#   'age': 26,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 157.0,
#   'assets': 7000.0,
#   'debt': 0.0,
#   'amount': 1200,
#   'price': 2053},
#  {'seniority': 3,
#   'home': 'rent',
#   'time': 48,
#   'age': 39,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 97,
#   'income': 223.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1250,
#   'price': 1609},
#  {'seniority': 20,
#   'home': 'owner',
#   'time': 36,
#   'age': 40,
#   'marital': 'single',
#   'records': 'yes',
#   'job': 'freelance',
#   'expenses': 35,
#   'income': 0.0,
#   'assets': 8500.0,
#   'debt': 400.0,
#   'amount': 750,
#   'price': 1100},
#  {'seniority': 0,
#   'home': 'owner',
#   'time': 36,
#   'age': 42,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 105,
#   'income': 75.0,
#   'assets': 10000.0,
#   'debt': 0.0,
#   'amount': 400,
#   'price': 725},
#  {'seniority': 23,
#   'home': 'private',
#   'time': 60,
#   'age': 51,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 110.0,
#   'assets': 2500.0,
#   'debt': 0.0,
#   'amount': 800,
#   'price': 1343},
#  {'seniority': 5,
#   'home': 'rent',
#   'time': 36,
#   'age': 51,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 63,
#   'income': 184.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 635,
#   'price': 785},
#  {'seniority': 6,
#   'home': 'rent',
#   'time': 60,
#   'age': 34,
#   'marital': 'separated',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 47,
#   'income': 120.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1100,
#   'price': 1700},
#  {'seniority': 12,
#   'home': 'owner',
#   'time': 24,
#   'age': 38,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 114.0,
#   'assets': 4000.0,
#   'debt': 600.0,
#   'amount': 400,
#   'price': 1169},
#  {'seniority': 0,
#   'home': 'owner',
#   'time': 60,
#   'age': 24,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'others',
#   'expenses': 35,
#   'income': 104.0,
#   'assets': 7000.0,
#   'debt': 2500.0,
#   'amount': 1350,
#   'price': 1425},
#  {'seniority': 10,
#   'home': 'private',
#   'time': 48,
#   'age': 28,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 129.0,
#   'assets': 3500.0,
#   'debt': 933.0,
#   'amount': 1000,
#   'price': 1529},
#  {'seniority': 3,
#   'home': 'parents',
#   'time': 48,
#   'age': 24,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 55.0,
#   'assets': 3000.0,
#   'debt': 0.0,
#   'amount': 850,
#   'price': 875},
#  {'seniority': 3,
#   'home': 'private',
#   'time': 6,
#   'age': 24,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 173.0,
#   'assets': 4800.0,
#   'debt': 0.0,
#   'amount': 475,
#   'price': 1323},
#  {'seniority': 10,
#   'home': 'rent',
#   'time': 60,
#   'age': 38,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 110,
#   'income': 204.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1500,
#   'price': 1531},
#  {'seniority': 8,
#   'home': 'other',
#   'time': 24,
#   'age': 33,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 166.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1150,
#   'price': 1770},
#  {'seniority': 1,
#   'home': 'rent',
#   'time': 60,
#   'age': 40,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 57,
#   'income': 120.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1500,
#   'price': 1737},
#  {'seniority': 2,
#   'home': 'owner',
#   'time': 60,
#   'age': 27,
#   'marital': 'single',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 120.0,
#   'assets': 8000.0,
#   'debt': 0.0,
#   'amount': 975,
#   'price': 1140},
#  {'seniority': 1,
#   'home': 'parents',
#   'time': 60,
#   'age': 30,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 113.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 930,
#   'price': 955},
#  {'seniority': 0,
#   'home': 'other',
#   'time': 36,
#   'age': 41,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'freelance',
#   'expenses': 35,
#   'income': 0.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1600},
#  {'seniority': 10,
#   'home': 'rent',
#   'time': 24,
#   'age': 39,
#   'marital': 'single',
#   'records': 'yes',
#   'job': 'others',
#   'expenses': 55,
#   'income': 195.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 400,
#   'price': 435},
#  {'seniority': 2,
#   'home': 'owner',
#   'time': 60,
#   'age': 36,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 190.0,
#   'assets': 4500.0,
#   'debt': 1200.0,
#   'amount': 1575,
#   'price': 1611},
#  {'seniority': 6,
#   'home': 'owner',
#   'time': 48,
#   'age': 24,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 227.0,
#   'assets': 3000.0,
#   'debt': 0.0,
#   'amount': 600,
#   'price': 1380},
#  {'seniority': 0,
#   'home': 'rent',
#   'time': 60,
#   'age': 21,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 35,
#   'income': 0.0,
#   'assets': 16000.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1000},
#  {'seniority': 20,
#   'home': 'parents',
#   'time': 36,
#   'age': 38,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'freelance',
#   'expenses': 60,
#   'income': 0.0,
#   'assets': 25000.0,
#   'debt': 0.0,
#   'amount': 1500,
#   'price': 1650},
#  {'seniority': 2,
#   'home': 'parents',
#   'time': 60,
#   'age': 24,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 164.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 900,
#   'price': 1516},
#  {'seniority': 10,
#   'home': 'owner',
#   'time': 60,
#   'age': 45,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 45,
#   'income': 325.0,
#   'assets': 12000.0,
#   'debt': 1200.0,
#   'amount': 1300,
#   'price': 1833},
#  {'seniority': 10,
#   'home': 'private',
#   'time': 36,
#   'age': 61,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 130.0,
#   'assets': 25000.0,
#   'debt': 0.0,
#   'amount': 350,
#   'price': 400},
#  {'seniority': 1,
#   'home': 'rent',
#   'time': 60,
#   'age': 28,
#   'marital': 'single',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 47,
#   'income': 120.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1400,
#   'price': 1690},
#  {'seniority': 13,
#   'home': 'rent',
#   'time': 36,
#   'age': 36,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 88,
#   'income': 130.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 400,
#   'price': 1608},
#  {'seniority': 13,
#   'home': 'owner',
#   'time': 48,
#   'age': 27,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 118.0,
#   'assets': 10000.0,
#   'debt': 7200.0,
#   'amount': 1100,
#   'price': 1397},
#  {'seniority': 14,
#   'home': 'other',
#   'time': 48,
#   'age': 36,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 251.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1550},
#  {'seniority': 3,
#   'home': 'rent',
#   'time': 48,
#   'age': 33,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 45,
#   'income': 100.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1350,
#   'price': 1518},
#  {'seniority': 14,
#   'home': 'owner',
#   'time': 60,
#   'age': 28,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 198.0,
#   'assets': 7000.0,
#   'debt': 900.0,
#   'amount': 1000,
#   'price': 1850},
#  {'seniority': 18,
#   'home': 'rent',
#   'time': 24,
#   'age': 35,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 96,
#   'income': 63.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 600,
#   'price': 888},
#  {'seniority': 5,
#   'home': 'owner',
#   'time': 48,
#   'age': 55,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 90,
#   'income': 41.0,
#   'assets': 30000.0,
#   'debt': 0.0,
#   'amount': 850,
#   'price': 1344},
#  {'seniority': 22,
#   'home': 'owner',
#   'time': 60,
#   'age': 54,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 104.0,
#   'assets': 3000.0,
#   'debt': 0.0,
#   'amount': 1050,
#   'price': 1282},
#  {'seniority': 18,
#   'home': 'owner',
#   'time': 18,
#   'age': 50,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 75.0,
#   'assets': 3000.0,
#   'debt': 0.0,
#   'amount': 280,
#   'price': 434},
#  {'seniority': 0,
#   'home': 'other',
#   'time': 60,
#   'age': 51,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 60,
#   'income': 0.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1300,
#   'price': 1321},
#  {'seniority': 0,
#   'home': 'rent',
#   'time': 48,
#   'age': 23,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 42,
#   'income': 72.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 700,
#   'price': 875},
#  {'seniority': 1,
#   'home': 'owner',
#   'time': 60,
#   'age': 40,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 100.0,
#   'assets': 8500.0,
#   'debt': 0.0,
#   'amount': 400,
#   'price': 1570},
#  {'seniority': 2,
#   'home': 'owner',
#   'time': 60,
#   'age': 43,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 45,
#   'income': 0.0,
#   'assets': 16000.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1490},
#  {'seniority': 11,
#   'home': 'private',
#   'time': 36,
#   'age': 44,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 90,
#   'income': 89.0,
#   'assets': 2000.0,
#   'debt': 100.0,
#   'amount': 250,
#   'price': 450},
#  {'seniority': 13,
#   'home': 'parents',
#   'time': 60,
#   'age': 28,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 138.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1080,
#   'price': 1192},
#  {'seniority': 20,
#   'home': 'owner',
#   'time': 60,
#   'age': 37,
#   'marital': 'unk',
#   'records': 'yes',
#   'job': 'freelance',
#   'expenses': 35,
#   'income': 70.0,
#   'assets': 10000.0,
#   'debt': 0.0,
#   'amount': 1300,
#   'price': 1675},
#  {'seniority': 2,
#   'home': 'parents',
#   'time': 60,
#   'age': 25,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 45,
#   'income': 130.0,
#   'assets': 8500.0,
#   'debt': 0.0,
#   'amount': 1100,
#   'price': 1380},
#  {'seniority': 5,
#   'home': 'parents',
#   'time': 36,
#   'age': 22,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 100.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1200},
#  {'seniority': 5,
#   'home': 'owner',
#   'time': 42,
#   'age': 33,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 140.0,
#   'assets': 22000.0,
#   'debt': 2500.0,
#   'amount': 1200,
#   'price': 1888},
#  {'seniority': 1,
#   'home': 'rent',
#   'time': 24,
#   'age': 24,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 49,
#   'income': 139.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 500,
#   'price': 550},
#  {'seniority': 1,
#   'home': 'rent',
#   'time': 48,
#   'age': 28,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 75,
#   'income': 0.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 400,
#   'price': 1415},
#  {'seniority': 6,
#   'home': 'owner',
#   'time': 60,
#   'age': 43,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'freelance',
#   'expenses': 45,
#   'income': 140.0,
#   'assets': 4300.0,
#   'debt': 0.0,
#   'amount': 2200,
#   'price': 2500},
#  {'seniority': 5,
#   'home': 'owner',
#   'time': 60,
#   'age': 36,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 141.0,
#   'assets': 4000.0,
#   'debt': 0.0,
#   'amount': 1300,
#   'price': 1435},
#  {'seniority': 1,
#   'home': 'owner',
#   'time': 48,
#   'age': 31,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 201.0,
#   'assets': 2500.0,
#   'debt': 96.0,
#   'amount': 1100,
#   'price': 1642},
#  {'seniority': 3,
#   'home': 'owner',
#   'time': 60,
#   'age': 60,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'others',
#   'expenses': 45,
#   'income': 67.0,
#   'assets': 10000.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1683},
#  {'seniority': 13,
#   'home': 'owner',
#   'time': 48,
#   'age': 40,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 123.0,
#   'assets': 4000.0,
#   'debt': 0.0,
#   'amount': 900,
#   'price': 1054},
#  {'seniority': 2,
#   'home': 'owner',
#   'time': 60,
#   'age': 42,
#   'marital': 'widow',
#   'records': 'no',
#   'job': 'others',
#   'expenses': 45,
#   'income': 35.0,
#   'assets': 6000.0,
#   'debt': 0.0,
#   'amount': 650,
#   'price': 865},
#  {'seniority': 2,
#   'home': 'owner',
#   'time': 36,
#   'age': 27,
#   'marital': 'widow',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 135.0,
#   'assets': 8000.0,
#   'debt': 0.0,
#   'amount': 750,
#   'price': 1296},
#  {'seniority': 1,
#   'home': 'parents',
#   'time': 12,
#   'age': 24,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 128.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 300,
#   'price': 1056},
#  {'seniority': 5,
#   'home': 'owner',
#   'time': 42,
#   'age': 32,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 96.0,
#   'assets': 6000.0,
#   'debt': 800.0,
#   'amount': 1700,
#   'price': 2349},
#  {'seniority': 1,
#   'home': 'rent',
#   'time': 54,
#   'age': 36,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 70,
#   'income': 99.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 950,
#   'price': 950},
#  {'seniority': 7,
#   'home': 'rent',
#   'time': 36,
#   'age': 33,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 78,
#   'income': 178.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 700,
#   'price': 1033},
#  {'seniority': 1,
#   'home': 'rent',
#   'time': 60,
#   'age': 26,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 61,
#   'income': 155.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1035,
#   'price': 1709},
#  {'seniority': 1,
#   'home': 'parents',
#   'time': 18,
#   'age': 25,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 35,
#   'income': 47.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 400,
#   'price': 1367},
#  {'seniority': 10,
#   'home': 'owner',
#   'time': 18,
#   'age': 34,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 75,
#   'income': 181.0,
#   'assets': 4000.0,
#   'debt': 0.0,
#   'amount': 600,
#   'price': 1000},
#  {'seniority': 1,
#   'home': 'rent',
#   'time': 48,
#   'age': 42,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 94,
#   'income': 192.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1350,
#   'price': 1819},
#  {'seniority': 14,
#   'home': 'rent',
#   'time': 60,
#   'age': 46,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 67,
#   'income': 67.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1500,
#   'price': 2250},
#  {'seniority': 1,
#   'home': 'owner',
#   'time': 48,
#   'age': 36,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 75.0,
#   'assets': 5500.0,
#   'debt': 0.0,
#   'amount': 1085,
#   'price': 1736},
#  {'seniority': 1,
#   'home': 'owner',
#   'time': 36,
#   'age': 30,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 75,
#   'income': 0.0,
#   'assets': 6000.0,
#   'debt': 0.0,
#   'amount': 700,
#   'price': 850},
#  {'seniority': 22,
#   'home': 'private',
#   'time': 60,
#   'age': 36,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 190.0,
#   'assets': 3500.0,
#   'debt': 0.0,
#   'amount': 1300,
#   'price': 1579},
#  {'seniority': 4,
#   'home': 'parents',
#   'time': 12,
#   'age': 30,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 340.0,
#   'assets': 16000.0,
#   'debt': 0.0,
#   'amount': 1900,
#   'price': 2014},
#  {'seniority': 5,
#   'home': 'other',
#   'time': 36,
#   'age': 49,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'others',
#   'expenses': 60,
#   'income': 44.0,
#   'assets': 8000.0,
#   'debt': 0.0,
#   'amount': 400,
#   'price': 428},
#  {'seniority': 0,
#   'home': 'owner',
#   'time': 60,
#   'age': 50,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 250.0,
#   'assets': 15500.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1989},
#  {'seniority': 20,
#   'home': 'rent',
#   'time': 36,
#   'age': 39,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 95,
#   'income': 202.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 600,
#   'price': 1461},
#  {'seniority': 1,
#   'home': 'rent',
#   'time': 36,
#   'age': 44,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 105,
#   'income': 145.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 2275},
#  {'seniority': 7,
#   'home': 'owner',
#   'time': 36,
#   'age': 37,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'freelance',
#   'expenses': 90,
#   'income': 150.0,
#   'assets': 4500.0,
#   'debt': 3000.0,
#   'amount': 400,
#   'price': 882},
#  {'seniority': 10,
#   'home': 'parents',
#   'time': 36,
#   'age': 37,
#   'marital': 'single',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 150.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 2484},
#  {'seniority': 1,
#   'home': 'rent',
#   'time': 60,
#   'age': 31,
#   'marital': 'divorced',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 43,
#   'income': 76.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 500,
#   'price': 1300},
#  {'seniority': 8,
#   'home': 'owner',
#   'time': 24,
#   'age': 46,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 200.0,
#   'assets': 5000.0,
#   'debt': 0.0,
#   'amount': 740,
#   'price': 2095},
#  {'seniority': 20,
#   'home': 'rent',
#   'time': 60,
#   'age': 41,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 50,
#   'income': 148.0,
#   'assets': 4000.0,
#   'debt': 0.0,
#   'amount': 835,
#   'price': 1356},
#  {'seniority': 10,
#   'home': 'other',
#   'time': 60,
#   'age': 31,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 125.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1200,
#   'price': 1682},
#  {'seniority': 14,
#   'home': 'owner',
#   'time': 36,
#   'age': 39,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 200.0,
#   'assets': 5000.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1155},
#  {'seniority': 4,
#   'home': 'rent',
#   'time': 60,
#   'age': 34,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 84,
#   'income': 85.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 800,
#   'price': 1293},
#  {'seniority': 11,
#   'home': 'owner',
#   'time': 48,
#   'age': 26,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 135.0,
#   'assets': 3500.0,
#   'debt': 0.0,
#   'amount': 200,
#   'price': 1871},
#  {'seniority': 0,
#   'home': 'rent',
#   'time': 36,
#   'age': 22,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 42,
#   'income': 65.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 430,
#   'price': 550},
#  {'seniority': 2,
#   'home': 'other',
#   'time': 36,
#   'age': 35,
#   'marital': 'separated',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 200.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1600,
#   'price': 1671},
#  {'seniority': 1,
#   'home': 'parents',
#   'time': 60,
#   'age': 27,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 35,
#   'income': 82.0,
#   'assets': 8000.0,
#   'debt': 0.0,
#   'amount': 1100,
#   'price': 1300},
#  {'seniority': 2,
#   'home': 'rent',
#   'time': 60,
#   'age': 57,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'others',
#   'expenses': 50,
#   'income': 52.0,
#   'assets': 1800.0,
#   'debt': 0.0,
#   'amount': 800,
#   'price': 866},
#  {'seniority': 12,
#   'home': 'private',
#   'time': 24,
#   'age': 28,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 102.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 700,
#   'price': 1229},
#  {'seniority': 10,
#   'home': 'owner',
#   'time': 24,
#   'age': 50,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 60,
#   'income': 200.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 500,
#   'price': 1131},
#  {'seniority': 10,
#   'home': 'rent',
#   'time': 48,
#   'age': 47,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 52,
#   'income': 168.0,
#   'assets': 6000.0,
#   'debt': 0.0,
#   'amount': 850,
#   'price': 1720},
#  {'seniority': 2,
#   'home': 'parents',
#   'time': 48,
#   'age': 26,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 110.0,
#   'assets': 10000.0,
#   'debt': 0.0,
#   'amount': 1300,
#   'price': 1700},
#  {'seniority': 1,
#   'home': 'owner',
#   'time': 36,
#   'age': 36,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 100.0,
#   'assets': 7000.0,
#   'debt': 0.0,
#   'amount': 2000,
#   'price': 2500},
#  {'seniority': 9,
#   'home': 'owner',
#   'time': 48,
#   'age': 26,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 101.0,
#   'assets': 5000.0,
#   'debt': 0.0,
#   'amount': 500,
#   'price': 1997},
#  {'seniority': 0,
#   'home': 'parents',
#   'time': 36,
#   'age': 24,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 35,
#   'income': 59.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 500,
#   'price': 1400},
#  {'seniority': 2,
#   'home': 'owner',
#   'time': 60,
#   'age': 38,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 74.0,
#   'assets': 3500.0,
#   'debt': 500.0,
#   'amount': 1700,
#   'price': 1888},
#  {'seniority': 13,
#   'home': 'parents',
#   'time': 36,
#   'age': 27,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 105.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 500,
#   'price': 800},
#  {'seniority': 0,
#   'home': 'owner',
#   'time': 60,
#   'age': 32,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 35,
#   'income': 94.0,
#   'assets': 7500.0,
#   'debt': 0.0,
#   'amount': 1350,
#   'price': 1583},
#  {'seniority': 17,
#   'home': 'owner',
#   'time': 48,
#   'age': 49,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 60,
#   'income': 189.0,
#   'assets': 7000.0,
#   'debt': 0.0,
#   'amount': 1100,
#   'price': 1294},
#  {'seniority': 1,
#   'home': 'owner',
#   'time': 36,
#   'age': 19,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 98.0,
#   'assets': 4000.0,
#   'debt': 0.0,
#   'amount': 200,
#   'price': 1330},
#  {'seniority': 17,
#   'home': 'owner',
#   'time': 60,
#   'age': 32,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 200.0,
#   'assets': 5000.0,
#   'debt': 2500.0,
#   'amount': 1550,
#   'price': 1721},
#  {'seniority': 2,
#   'home': 'other',
#   'time': 36,
#   'age': 26,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 63.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 300,
#   'price': 1111},
#  {'seniority': 0,
#   'home': 'parents',
#   'time': 24,
#   'age': 36,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'others',
#   'expenses': 90,
#   'income': 31.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 625,
#   'price': 725},
#  {'seniority': 4,
#   'home': 'owner',
#   'time': 24,
#   'age': 44,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 75,
#   'income': 86.0,
#   'assets': 5000.0,
#   'debt': 0.0,
#   'amount': 900,
#   'price': 1100},
#  {'seniority': 10,
#   'home': 'parents',
#   'time': 36,
#   'age': 27,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 150.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1788},
#  {'seniority': 0,
#   'home': 'owner',
#   'time': 60,
#   'age': 22,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 45,
#   'income': 150.0,
#   'assets': 4000.0,
#   'debt': 0.0,
#   'amount': 1550,
#   'price': 1657},
#  {'seniority': 7,
#   'home': 'parents',
#   'time': 6,
#   'age': 28,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 93.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 600,
#   'price': 1827},
#  {'seniority': 7,
#   'home': 'rent',
#   'time': 60,
#   'age': 40,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'freelance',
#   'expenses': 76,
#   'income': 164.0,
#   'assets': 3000.0,
#   'debt': 0.0,
#   'amount': 800,
#   'price': 1032},
#  {'seniority': 7,
#   'home': 'owner',
#   'time': 36,
#   'age': 49,
#   'marital': 'widow',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 108.0,
#   'assets': 12000.0,
#   'debt': 0.0,
#   'amount': 350,
#   'price': 875},
#  {'seniority': 5,
#   'home': 'owner',
#   'time': 60,
#   'age': 31,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 172.0,
#   'assets': 8000.0,
#   'debt': 0.0,
#   'amount': 850,
#   'price': 1934},
#  {'seniority': 3,
#   'home': 'other',
#   'time': 48,
#   'age': 38,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 75,
#   'income': 40.0,
#   'assets': 3500.0,
#   'debt': 0.0,
#   'amount': 600,
#   'price': 882},
#  {'seniority': 3,
#   'home': 'rent',
#   'time': 48,
#   'age': 52,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 96,
#   'income': 210.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1400,
#   'price': 1419},
#  {'seniority': 2,
#   'home': 'parents',
#   'time': 48,
#   'age': 28,
#   'marital': 'separated',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 35,
#   'income': 140.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1100},
#  {'seniority': 0,
#   'home': 'rent',
#   'time': 60,
#   'age': 36,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 85,
#   'income': 100.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1100,
#   'price': 1256},
#  {'seniority': 0,
#   'home': 'parents',
#   'time': 48,
#   'age': 20,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 35,
#   'income': 215.0,
#   'assets': 15000.0,
#   'debt': 0.0,
#   'amount': 1100,
#   'price': 1100},
#  {'seniority': 1,
#   'home': 'parents',
#   'time': 12,
#   'age': 26,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 35,
#   'income': 0.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 190,
#   'price': 693},
#  {'seniority': 14,
#   'home': 'owner',
#   'time': 18,
#   'age': 29,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 165.0,
#   'assets': 6000.0,
#   'debt': 2500.0,
#   'amount': 600,
#   'price': 1370},
#  {'seniority': 5,
#   'home': 'owner',
#   'time': 18,
#   'age': 28,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 141.0,
#   'assets': 5500.0,
#   'debt': 0.0,
#   'amount': 650,
#   'price': 1258},
#  {'seniority': 2,
#   'home': 'other',
#   'time': 60,
#   'age': 37,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 0.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1385,
#   'price': 1385},
#  {'seniority': 8,
#   'home': 'other',
#   'time': 36,
#   'age': 29,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 170.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 800,
#   'price': 1000},
#  {'seniority': 0,
#   'home': 'rent',
#   'time': 60,
#   'age': 32,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 105,
#   'income': 301.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1200,
#   'price': 1274},
#  {'seniority': 3,
#   'home': 'owner',
#   'time': 18,
#   'age': 40,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 140.0,
#   'assets': 4000.0,
#   'debt': 0.0,
#   'amount': 400,
#   'price': 1772},
#  {'seniority': 4,
#   'home': 'parents',
#   'time': 60,
#   'age': 26,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 52.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1050,
#   'price': 1372},
#  {'seniority': 25,
#   'home': 'rent',
#   'time': 24,
#   'age': 45,
#   'marital': 'separated',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 53,
#   'income': 183.0,
#   'assets': 93000.0,
#   'debt': 0.0,
#   'amount': 1900,
#   'price': 3088},
#  {'seniority': 1,
#   'home': 'parents',
#   'time': 36,
#   'age': 29,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 66.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 700,
#   'price': 1018},
#  {'seniority': 14,
#   'home': 'owner',
#   'time': 36,
#   'age': 33,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 35,
#   'income': 0.0,
#   'assets': 4000.0,
#   'debt': 1500.0,
#   'amount': 700,
#   'price': 1700},
#  {'seniority': 13,
#   'home': 'rent',
#   'time': 60,
#   'age': 50,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 42,
#   'income': 66.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 800,
#   'price': 865},
#  {'seniority': 12,
#   'home': 'other',
#   'time': 60,
#   'age': 36,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 99.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 750,
#   'price': 790},
#  {'seniority': 2,
#   'home': 'owner',
#   'time': 60,
#   'age': 45,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 75,
#   'income': 75.0,
#   'assets': 2500.0,
#   'debt': 0.0,
#   'amount': 1100,
#   'price': 1242},
#  {'seniority': 10,
#   'home': 'owner',
#   'time': 60,
#   'age': 27,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 35,
#   'income': 180.0,
#   'assets': 8000.0,
#   'debt': 3530.0,
#   'amount': 1700,
#   'price': 1847},
#  {'seniority': 11,
#   'home': 'owner',
#   'time': 36,
#   'age': 55,
#   'marital': 'divorced',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 182.0,
#   'assets': 2000.0,
#   'debt': 0.0,
#   'amount': 500,
#   'price': 1135},
#  {'seniority': 3,
#   'home': 'parents',
#   'time': 36,
#   'age': 24,
#   'marital': 'separated',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 113.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 850,
#   'price': 940},
#  {'seniority': 5,
#   'home': 'other',
#   'time': 60,
#   'age': 42,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 95.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1067},
#  {'seniority': 8,
#   'home': 'owner',
#   'time': 60,
#   'age': 28,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 180.0,
#   'assets': 4000.0,
#   'debt': 0.0,
#   'amount': 1300,
#   'price': 1730},
#  {'seniority': 14,
#   'home': 'parents',
#   'time': 24,
#   'age': 28,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 192.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1736},
#  {'seniority': 2,
#   'home': 'parents',
#   'time': 36,
#   'age': 30,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'partime',
#   'expenses': 60,
#   'income': 203.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 600,
#   'price': 1549},
#  {'seniority': 20,
#   'home': 'other',
#   'time': 60,
#   'age': 62,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'others',
#   'expenses': 75,
#   'income': 140.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1300,
#   'price': 1371},
#  {'seniority': 10,
#   'home': 'owner',
#   'time': 60,
#   'age': 50,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 35,
#   'income': 0.0,
#   'assets': 3500.0,
#   'debt': 0.0,
#   'amount': 700,
#   'price': 985},
#  {'seniority': 1,
#   'home': 'parents',
#   'time': 60,
#   'age': 36,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 60,
#   'income': 60.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1400,
#   'price': 1612},
#  {'seniority': 19,
#   'home': 'owner',
#   'time': 60,
#   'age': 56,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 169.0,
#   'assets': 7000.0,
#   'debt': 0.0,
#   'amount': 1400,
#   'price': 1714},
#  {'seniority': 5,
#   'home': 'owner',
#   'time': 60,
#   'age': 40,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 134.0,
#   'assets': 3500.0,
#   'debt': 0.0,
#   'amount': 1200,
#   'price': 1291},
#  {'seniority': 6,
#   'home': 'parents',
#   'time': 24,
#   'age': 27,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 149.0,
#   'assets': 6500.0,
#   'debt': 0.0,
#   'amount': 850,
#   'price': 1340},
#  {'seniority': 0,
#   'home': 'private',
#   'time': 48,
#   'age': 45,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 194.0,
#   'assets': 3000.0,
#   'debt': 100.0,
#   'amount': 1000,
#   'price': 1429},
#  {'seniority': 6,
#   'home': 'owner',
#   'time': 60,
#   'age': 29,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 115.0,
#   'assets': 6000.0,
#   'debt': 2000.0,
#   'amount': 1250,
#   'price': 1780},
#  {'seniority': 15,
#   'home': 'owner',
#   'time': 48,
#   'age': 51,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 85.0,
#   'assets': 4000.0,
#   'debt': 0.0,
#   'amount': 600,
#   'price': 1298},
#  {'seniority': 5,
#   'home': 'parents',
#   'time': 24,
#   'age': 31,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 130.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 200,
#   'price': 1447},
#  {'seniority': 15,
#   'home': 'rent',
# ...
#   'job': 'freelance',
#   'expenses': 75,
#   'income': 411.0,
#   'assets': 9000.0,
#   'debt': 4000.0,
#   'amount': 800,
#   'price': 1593},
#  {'seniority': 5,
#   'home': 'owner',
#   'time': 60,
#   'age': 32,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 145.0,
#   'assets': 13000.0,
#   'debt': 0.0,
#   'amount': 1500,
#   'price': 1850},
#  {'seniority': 40,
#   'home': 'owner',
#   'time': 36,
#   'age': 58,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 75,
#   'income': 0.0,
#   'assets': 50000.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1160},
#  {'seniority': 4,
#   'home': 'owner',
#   'time': 60,
#   'age': 55,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 60,
#   'income': 350.0,
#   'assets': 13000.0,
#   'debt': 3000.0,
#   'amount': 1700,
#   'price': 2200},
#  {'seniority': 7,
#   'home': 'parents',
#   'time': 36,
#   'age': 24,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 127.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 300,
#   'price': 2612},
#  {'seniority': 1,
#   'home': 'parents',
#   'time': 48,
#   'age': 18,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 35,
#   'income': 81.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1150,
#   'price': 1314},
#  {'seniority': 0,
#   'home': 'parents',
#   'time': 48,
#   'age': 26,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 45,
#   'income': 76.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 700,
#   'price': 2300},
#  {'seniority': 27,
#   'home': 'owner',
#   'time': 60,
#   'age': 58,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 60,
#   'income': 60.0,
#   'assets': 15000.0,
#   'debt': 0.0,
#   'amount': 1450,
#   'price': 1657},
#  {'seniority': 0,
#   'home': 'owner',
#   'time': 24,
#   'age': 20,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'others',
#   'expenses': 60,
#   'income': 152.0,
#   'assets': 2000.0,
#   'debt': 0.0,
#   'amount': 400,
#   'price': 480},
#  {'seniority': 14,
#   'home': 'owner',
#   'time': 12,
#   'age': 37,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 90,
#   'income': 500.0,
#   'assets': 4000.0,
#   'debt': 0.0,
#   'amount': 500,
#   'price': 1338},
#  {'seniority': 5,
#   'home': 'owner',
#   'time': 60,
#   'age': 37,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'freelance',
#   'expenses': 75,
#   'income': 75.0,
#   'assets': 12000.0,
#   'debt': 0.0,
#   'amount': 900,
#   'price': 1014},
#  {'seniority': 5,
#   'home': 'parents',
#   'time': 60,
#   'age': 21,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 60.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1100,
#   'price': 1134},
#  {'seniority': 5,
#   'home': 'parents',
#   'time': 60,
#   'age': 28,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 176.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1190,
#   'price': 1390},
#  {'seniority': 15,
#   'home': 'owner',
#   'time': 48,
#   'age': 34,
#   'marital': 'separated',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 45,
#   'income': 0.0,
#   'assets': 5000.0,
#   'debt': 0.0,
#   'amount': 900,
#   'price': 1197},
#  {'seniority': 11,
#   'home': 'owner',
#   'time': 48,
#   'age': 34,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 90,
#   'income': 198.0,
#   'assets': 4500.0,
#   'debt': 0.0,
#   'amount': 1650,
#   'price': 2165},
#  {'seniority': 1,
#   'home': 'parents',
#   'time': 48,
#   'age': 21,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 60.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 850,
#   'price': 1195},
#  {'seniority': 7,
#   'home': 'parents',
#   'time': 60,
#   'age': 25,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 58.0,
#   'assets': 28000.0,
#   'debt': 0.0,
#   'amount': 1100,
#   'price': 1338},
#  {'seniority': 1,
#   'home': 'rent',
#   'time': 36,
#   'age': 27,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 42,
#   'income': 67.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1350},
#  {'seniority': 8,
#   'home': 'owner',
#   'time': 48,
#   'age': 53,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 147.0,
#   'assets': 8000.0,
#   'debt': 700.0,
#   'amount': 750,
#   'price': 797},
#  {'seniority': 8,
#   'home': 'parents',
#   'time': 60,
#   'age': 33,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 75,
#   'income': 160.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1200,
#   'price': 1506},
#  {'seniority': 0,
#   'home': 'other',
#   'time': 60,
#   'age': 40,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 260.0,
#   'assets': 2500.0,
#   'debt': 0.0,
#   'amount': 1500,
#   'price': 1607},
#  {'seniority': 1,
#   'home': 'owner',
#   'time': 36,
#   'age': 48,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'others',
#   'expenses': 45,
#   'income': 45.0,
#   'assets': 32000.0,
#   'debt': 0.0,
#   'amount': 1500,
#   'price': 2700},
#  {'seniority': 2,
#   'home': 'parents',
#   'time': 48,
#   'age': 33,
#   'marital': 'single',
#   'records': 'yes',
#   'job': 'partime',
#   'expenses': 35,
#   'income': 82.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1050,
#   'price': 1332},
#  {'seniority': 0,
#   'home': 'owner',
#   'time': 48,
#   'age': 31,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 122.0,
#   'assets': 4000.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1541},
#  {'seniority': 15,
#   'home': 'parents',
#   'time': 36,
#   'age': 39,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 120.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 900,
#   'price': 900},
#  {'seniority': 1,
#   'home': 'owner',
#   'time': 42,
#   'age': 35,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 54.0,
#   'assets': 6000.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1900},
#  {'seniority': 15,
#   'home': 'owner',
#   'time': 24,
#   'age': 47,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'freelance',
#   'expenses': 45,
#   'income': 0.0,
#   'assets': 5000.0,
#   'debt': 0.0,
#   'amount': 250,
#   'price': 500},
#  {'seniority': 8,
#   'home': 'rent',
#   'time': 60,
#   'age': 25,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 73,
#   'income': 280.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 600,
#   'price': 1364},
#  {'seniority': 10,
#   'home': 'other',
#   'time': 36,
#   'age': 45,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 102.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 535,
#   'price': 585},
#  {'seniority': 13,
#   'home': 'owner',
#   'time': 24,
#   'age': 32,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 305.0,
#   'assets': 8000.0,
#   'debt': 0.0,
#   'amount': 1400,
#   'price': 2060},
#  {'seniority': 2,
#   'home': 'owner',
#   'time': 36,
#   'age': 30,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 35,
#   'income': 0.0,
#   'assets': 4000.0,
#   'debt': 0.0,
#   'amount': 1100,
#   'price': 1850},
#  {'seniority': 13,
#   'home': 'private',
#   'time': 60,
#   'age': 33,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 224.0,
#   'assets': 7000.0,
#   'debt': 0.0,
#   'amount': 1600,
#   'price': 1604},
#  {'seniority': 3,
#   'home': 'rent',
#   'time': 60,
#   'age': 24,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 54,
#   'income': 90.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1442,
#   'price': 1597},
#  {'seniority': 1,
#   'home': 'owner',
#   'time': 60,
#   'age': 29,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 275.0,
#   'assets': 6000.0,
#   'debt': 1810.0,
#   'amount': 1600,
#   'price': 1930},
#  {'seniority': 13,
#   'home': 'rent',
#   'time': 60,
#   'age': 36,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 79,
#   'income': 191.0,
#   'assets': 4000.0,
#   'debt': 700.0,
#   'amount': 1000,
#   'price': 1209},
#  {'seniority': 1,
#   'home': 'rent',
#   'time': 24,
#   'age': 32,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 35,
#   'income': 0.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 290,
#   'price': 490},
#  {'seniority': 1,
#   'home': 'rent',
#   'time': 60,
#   'age': 26,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 42,
#   'income': 74.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 750,
#   'price': 778},
#  {'seniority': 0,
#   'home': 'other',
#   'time': 60,
#   'age': 21,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 35,
#   'income': 0.0,
#   'assets': 4000.0,
#   'debt': 0.0,
#   'amount': 1250,
#   'price': 1300},
#  {'seniority': 29,
#   'home': 'owner',
#   'time': 48,
#   'age': 52,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 60,
#   'income': 118.0,
#   'assets': 6500.0,
#   'debt': 0.0,
#   'amount': 750,
#   'price': 1255},
#  {'seniority': 6,
#   'home': 'other',
#   'time': 24,
#   'age': 23,
#   'marital': 'single',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 135.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 250,
#   'price': 250},
#  {'seniority': 17,
#   'home': 'owner',
#   'time': 60,
#   'age': 44,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 116.0,
#   'assets': 3000.0,
#   'debt': 0.0,
#   'amount': 800,
#   'price': 1654},
#  {'seniority': 12,
#   'home': 'private',
#   'time': 12,
#   'age': 41,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 75,
#   'income': 111.0,
#   'assets': 20000.0,
#   'debt': 0.0,
#   'amount': 1200,
#   'price': 2130},
#  {'seniority': 4,
#   'home': 'private',
#   'time': 60,
#   'age': 37,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 75,
#   'income': 120.0,
#   'assets': 10500.0,
#   'debt': 1500.0,
#   'amount': 1200,
#   'price': 1341},
#  {'seniority': 1,
#   'home': 'owner',
#   'time': 12,
#   'age': 56,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'others',
#   'expenses': 60,
#   'income': 0.0,
#   'assets': 3500.0,
#   'debt': 0.0,
#   'amount': 500,
#   'price': 1705},
#  {'seniority': 1,
#   'home': 'parents',
#   'time': 36,
#   'age': 31,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 61.0,
#   'assets': 4000.0,
#   'debt': 0.0,
#   'amount': 700,
#   'price': 800},
#  {'seniority': 14,
#   'home': 'ignore',
#   'time': 60,
#   'age': 34,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 85.0,
#   'assets': 8000.0,
#   'debt': 0.0,
#   'amount': 1400,
#   'price': 1589},
#  {'seniority': 13,
#   'home': 'owner',
#   'time': 36,
#   'age': 59,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 170.0,
#   'assets': 6000.0,
#   'debt': 0.0,
#   'amount': 700,
#   'price': 844},
#  {'seniority': 30,
#   'home': 'owner',
#   'time': 60,
#   'age': 53,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 35,
#   'income': 201.0,
#   'assets': 25000.0,
#   'debt': 0.0,
#   'amount': 1360,
#   'price': 1450},
#  {'seniority': 2,
#   'home': 'parents',
#   'time': 60,
#   'age': 34,
#   'marital': 'single',
#   'records': 'yes',
#   'job': 'partime',
#   'expenses': 35,
#   'income': 103.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1250,
#   'price': 1293},
#  {'seniority': 37,
#   'home': 'owner',
#   'time': 60,
#   'age': 56,
#   'marital': 'widow',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 300.0,
#   'assets': 10000.0,
#   'debt': 0.0,
#   'amount': 1300,
#   'price': 1750},
#  {'seniority': 0,
#   'home': 'rent',
#   'time': 60,
#   'age': 46,
#   'marital': 'separated',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 57,
#   'income': 124.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 940,
#   'price': 1149},
#  {'seniority': 13,
#   'home': 'owner',
#   'time': 60,
#   'age': 40,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 90,
#   'income': 130.0,
#   'assets': 3000.0,
#   'debt': 0.0,
#   'amount': 800,
#   'price': 860},
#  {'seniority': 20,
#   'home': 'rent',
#   'time': 60,
#   'age': 52,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 70,
#   'income': 250.0,
#   'assets': 4100.0,
#   'debt': 0.0,
#   'amount': 1200,
#   'price': 1226},
#  {'seniority': 5,
#   'home': 'rent',
#   'time': 36,
#   'age': 28,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 60,
#   'income': 0.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 900,
#   'price': 1200},
#  {'seniority': 12,
#   'home': 'owner',
#   'time': 60,
#   'age': 54,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 231.0,
#   'assets': 15000.0,
#   'debt': 0.0,
#   'amount': 1950,
#   'price': 2500},
#  {'seniority': 1,
#   'home': 'rent',
#   'time': 48,
#   'age': 39,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 86,
#   'income': 105.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1300,
#   'price': 1600},
#  {'seniority': 3,
#   'home': 'private',
#   'time': 36,
#   'age': 38,
#   'marital': 'divorced',
#   'records': 'yes',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 0.0,
#   'assets': 12500.0,
#   'debt': 0.0,
#   'amount': 3000,
#   'price': 4800},
#  {'seniority': 1,
#   'home': 'rent',
#   'time': 60,
#   'age': 27,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 44,
#   'income': 88.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1092},
#  {'seniority': 4,
#   'home': 'rent',
#   'time': 48,
#   'age': 27,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 58,
#   'income': 125.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1200,
#   'price': 1580},
#  {'seniority': 15,
#   'home': 'other',
#   'time': 24,
#   'age': 46,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 150.0,
#   'assets': 18000.0,
#   'debt': 0.0,
#   'amount': 1400,
#   'price': 1400},
#  {'seniority': 2,
#   'home': 'parents',
#   'time': 60,
#   'age': 26,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 45,
#   'income': 199.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1500,
#   'price': 1698},
#  {'seniority': 8,
#   'home': 'owner',
#   'time': 60,
#   'age': 56,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 45,
#   'income': 200.0,
#   'assets': 30000.0,
#   'debt': 0.0,
#   'amount': 1400,
#   'price': 1500},
#  {'seniority': 5,
#   'home': 'other',
#   'time': 48,
#   'age': 22,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 35,
#   'income': 82.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 480,
#   'price': 1910},
#  {'seniority': 1,
#   'home': 'owner',
#   'time': 12,
#   'age': 61,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'others',
#   'expenses': 35,
#   'income': 58.0,
#   'assets': 18000.0,
#   'debt': 0.0,
#   'amount': 500,
#   'price': 1342},
#  {'seniority': 2,
#   'home': 'owner',
#   'time': 48,
#   'age': 41,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 75,
#   'income': 120.0,
#   'assets': 7500.0,
#   'debt': 4750.0,
#   'amount': 900,
#   'price': 1411},
#  {'seniority': 1,
#   'home': 'rent',
#   'time': 60,
#   'age': 35,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 83,
#   'income': 76.0,
#   'assets': 10000.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1350},
#  {'seniority': 8,
#   'home': 'rent',
#   'time': 60,
#   'age': 52,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 89,
#   'income': 137.0,
#   'assets': 4000.0,
#   'debt': 0.0,
#   'amount': 800,
#   'price': 1086},
#  {'seniority': 6,
#   'home': 'rent',
#   'time': 60,
#   'age': 47,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'freelance',
#   'expenses': 45,
#   'income': 0.0,
#   'assets': 3000.0,
#   'debt': 0.0,
#   'amount': 1000,
#   'price': 1000},
#  {'seniority': 2,
#   'home': 'rent',
#   'time': 48,
#   'age': 23,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'partime',
#   'expenses': 51,
#   'income': 158.0,
#   'assets': 0.0,
#   'debt': 0.0,
#   'amount': 1300,
#   'price': 1700},
#  ...]

# %%
dv = DictVectorizer(sparse=False)
X_train = dv.fit_transform(train_dicts)

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
val_dicts = df_val.fillna(0).to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
y_pred = dt.predict_proba(X_val)[:, 1]
roc_auc_score(y_val, y_pred)
# Out:
# np.float64(0.6629319948657092)

# %%
y_pred = dt.predict_proba(X_train)[:, 1]
roc_auc_score(y_train, y_pred)
# Out:
# np.float64(1.0)

# %%
dt = DecisionTreeClassifier(max_depth=3)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
y_pred = dt.predict_proba(X_train)[:, 1]
auc = roc_auc_score(y_train, y_pred)
print('train:', auc)

y_pred = dt.predict_proba(X_val)[:, 1]
auc = roc_auc_score(y_val, y_pred)
print('val:', auc)
# Out:
# train: 0.7761016984958594
# val: 0.7389079944782155

# %%
print(export_text(dt, feature_names=list(dv.get_feature_names_out())))
# Out:
# |--- records=yes <= 0.50
# |   |--- job=partime <= 0.50
# |   |   |--- income <= 74.50
# |   |   |   |--- class: 0
# |   |   |--- income >  74.50
# |   |   |   |--- class: 0
# |   |--- job=partime >  0.50
# |   |   |--- assets <= 8750.00
# |   |   |   |--- class: 1
# |   |   |--- assets >  8750.00
# |   |   |   |--- class: 0
# |--- records=yes >  0.50
# |   |--- seniority <= 6.50
# |   |   |--- amount <= 862.50
# |   |   |   |--- class: 0
# |   |   |--- amount >  862.50
# |   |   |   |--- class: 1
# |   |--- seniority >  6.50
# |   |   |--- income <= 103.50
# |   |   |   |--- class: 1
# |   |   |--- income >  103.50
# |   |   |   |--- class: 0

# %% [markdown]
# 6.4 Decision tree learning algorithm

# %%
data = [
    [8000, 'default'],
    [2000, 'default'],
    [   0, 'default'],
    [5000, 'ok'],
    [5000, 'ok'],
    [4000, 'ok'],
    [9000, 'ok'],
    [3000, 'default'],
]

df_example = pd.DataFrame(data, columns=['assets', 'status'])
df_example
# Out:
#    assets   status
# 0    8000  default
# 1    2000  default
# 2       0  default
# 3    5000       ok
# 4    5000       ok
# 5    4000       ok
# 6    9000       ok
# 7    3000  default

# %%
df_example.sort_values('assets')
# Out:
#    assets   status
# 2       0  default
# 1    2000  default
# 7    3000  default
# 5    4000       ok
# 3    5000       ok
# 4    5000       ok
# 0    8000  default
# 6    9000       ok

# %%
Ts = [0, 2000, 3000, 4000, 5000, 8000]

# %%
T = 4000
df_left = df_example[df_example.assets <= T]
df_right = df_example[df_example.assets > T]

display(df_left)
print(df_left.status.value_counts(normalize=True))
display(df_right)
print(df_left.status.value_counts(normalize=True))
# Out:
#    assets   status
# 1    2000  default
# 2       0  default
# 5    4000       ok
# 7    3000  default
# status
# default    0.75
# ok         0.25
# Name: proportion, dtype: float64
#    assets   status
# 0    8000  default
# 3    5000       ok
# 4    5000       ok
# 6    9000       ok
# status
# default    0.75
# ok         0.25
# Name: proportion, dtype: float64

# %%
from IPython.display import display

# %%
for T in Ts:
    print(T)
    df_left = df_example[df_example.assets <= T]
    df_right = df_example[df_example.assets > T]
    
    display(df_left)
    print(df_left.status.value_counts(normalize=True))
    display(df_right)
    print(df_right.status.value_counts(normalize=True))

    print()
# Out:
# 0
#    assets   status
# 2       0  default
# status
# default    1.0
# Name: proportion, dtype: float64
#    assets   status
# 0    8000  default
# 1    2000  default
# 3    5000       ok
# 4    5000       ok
# 5    4000       ok
# 6    9000       ok
# 7    3000  default
# status
# ok         0.571429
# default    0.428571
# Name: proportion, dtype: float64
#
# 2000
#    assets   status
# 1    2000  default
# 2       0  default
# status
# default    1.0
# Name: proportion, dtype: float64
#    assets   status
# 0    8000  default
# 3    5000       ok
# 4    5000       ok
# 5    4000       ok
# 6    9000       ok
# 7    3000  default
# status
# ok         0.666667
# default    0.333333
# Name: proportion, dtype: float64
#
# 3000
#    assets   status
# 1    2000  default
# 2       0  default
# 7    3000  default
# status
# default    1.0
# Name: proportion, dtype: float64
#    assets   status
# 0    8000  default
# 3    5000       ok
# 4    5000       ok
# 5    4000       ok
# 6    9000       ok
# status
# ok         0.8
# default    0.2
# Name: proportion, dtype: float64
#
# 4000
#    assets   status
# 1    2000  default
# 2       0  default
# 5    4000       ok
# 7    3000  default
# status
# default    0.75
# ok         0.25
# Name: proportion, dtype: float64
#    assets   status
# 0    8000  default
# 3    5000       ok
# 4    5000       ok
# 6    9000       ok
# status
# ok         0.75
# default    0.25
# Name: proportion, dtype: float64
#
# 5000
#    assets   status
# 1    2000  default
# 2       0  default
# 3    5000       ok
# 4    5000       ok
# 5    4000       ok
# 7    3000  default
# status
# default    0.5
# ok         0.5
# Name: proportion, dtype: float64
#    assets   status
# 0    8000  default
# 6    9000       ok
# status
# default    0.5
# ok         0.5
# Name: proportion, dtype: float64
#
# 8000
#    assets   status
# 0    8000  default
# 1    2000  default
# 2       0  default
# 3    5000       ok
# 4    5000       ok
# 5    4000       ok
# 7    3000  default
# status
# default    0.571429
# ok         0.428571
# Name: proportion, dtype: float64
#    assets status
# 6    9000     ok
# status
# ok    1.0
# Name: proportion, dtype: float64

# %%
data = [
    [8000, 3000, 'default'],
    [2000, 1000, 'default'],
    [   0, 1000, 'default'],
    [5000, 1000, 'ok'],
    [5000, 1000, 'ok'],
    [4000, 1000, 'ok'],
    [9000,  500, 'ok'],
    [3000, 2000, 'default'],
]

df_example = pd.DataFrame(data, columns=['assets', 'debt', 'status'])
df_example
# Out:
#    assets  debt   status
# 0    8000  3000  default
# 1    2000  1000  default
# 2       0  1000  default
# 3    5000  1000       ok
# 4    5000  1000       ok
# 5    4000  1000       ok
# 6    9000   500       ok
# 7    3000  2000  default

# %%
df_example.sort_values('debt')
# Out:
#    assets  debt   status
# 6    9000   500       ok
# 1    2000  1000  default
# 2       0  1000  default
# 3    5000  1000       ok
# 4    5000  1000       ok
# 5    4000  1000       ok
# 7    3000  2000  default
# 0    8000  3000  default

# %%
thresholds = {
    'assets': [0, 2000, 3000, 4000, 5000, 8000],
    'debt': [500, 1000, 2000]
}

# %%
for feature, Ts in thresholds.items():
    print('#####################')
    print(feature)
    for T in Ts:
        print(T)
        df_left = df_example[df_example[feature] <= T]
        df_right = df_example[df_example[feature] > T]

        display(df_left)
        print(df_left.status.value_counts(normalize=True))
        display(df_right)
        print(df_right.status.value_counts(normalize=True))

        print()
    print('#####################')
# Out:
# #####################
# assets
# 0
#    assets  debt   status
# 2       0  1000  default
# status
# default    1.0
# Name: proportion, dtype: float64
#    assets  debt   status
# 0    8000  3000  default
# 1    2000  1000  default
# 3    5000  1000       ok
# 4    5000  1000       ok
# 5    4000  1000       ok
# 6    9000   500       ok
# 7    3000  2000  default
# status
# ok         0.571429
# default    0.428571
# Name: proportion, dtype: float64
#
# 2000
#    assets  debt   status
# 1    2000  1000  default
# 2       0  1000  default
# status
# default    1.0
# Name: proportion, dtype: float64
#    assets  debt   status
# 0    8000  3000  default
# 3    5000  1000       ok
# 4    5000  1000       ok
# 5    4000  1000       ok
# 6    9000   500       ok
# 7    3000  2000  default
# status
# ok         0.666667
# default    0.333333
# Name: proportion, dtype: float64
#
# 3000
#    assets  debt   status
# 1    2000  1000  default
# 2       0  1000  default
# 7    3000  2000  default
# status
# default    1.0
# Name: proportion, dtype: float64
#    assets  debt   status
# 0    8000  3000  default
# 3    5000  1000       ok
# 4    5000  1000       ok
# 5    4000  1000       ok
# 6    9000   500       ok
# status
# ok         0.8
# default    0.2
# Name: proportion, dtype: float64
#
# 4000
#    assets  debt   status
# 1    2000  1000  default
# 2       0  1000  default
# 5    4000  1000       ok
# 7    3000  2000  default
# status
# default    0.75
# ok         0.25
# Name: proportion, dtype: float64
#    assets  debt   status
# 0    8000  3000  default
# 3    5000  1000       ok
# 4    5000  1000       ok
# 6    9000   500       ok
# status
# ok         0.75
# default    0.25
# Name: proportion, dtype: float64
#
# 5000
#    assets  debt   status
# 1    2000  1000  default
# 2       0  1000  default
# 3    5000  1000       ok
# 4    5000  1000       ok
# 5    4000  1000       ok
# 7    3000  2000  default
# status
# default    0.5
# ok         0.5
# Name: proportion, dtype: float64
#    assets  debt   status
# 0    8000  3000  default
# 6    9000   500       ok
# status
# default    0.5
# ok         0.5
# Name: proportion, dtype: float64
#
# 8000
#    assets  debt   status
# 0    8000  3000  default
# 1    2000  1000  default
# 2       0  1000  default
# 3    5000  1000       ok
# 4    5000  1000       ok
# 5    4000  1000       ok
# 7    3000  2000  default
# status
# default    0.571429
# ok         0.428571
# Name: proportion, dtype: float64
#    assets  debt status
# 6    9000   500     ok
# status
# ok    1.0
# Name: proportion, dtype: float64
#
# #####################
# #####################
# debt
# 500
#    assets  debt status
# 6    9000   500     ok
# status
# ok    1.0
# Name: proportion, dtype: float64
#    assets  debt   status
# 0    8000  3000  default
# 1    2000  1000  default
# 2       0  1000  default
# 3    5000  1000       ok
# 4    5000  1000       ok
# 5    4000  1000       ok
# 7    3000  2000  default
# status
# default    0.571429
# ok         0.428571
# Name: proportion, dtype: float64
#
# 1000
#    assets  debt   status
# 1    2000  1000  default
# 2       0  1000  default
# 3    5000  1000       ok
# 4    5000  1000       ok
# 5    4000  1000       ok
# 6    9000   500       ok
# status
# ok         0.666667
# default    0.333333
# Name: proportion, dtype: float64
#    assets  debt   status
# 0    8000  3000  default
# 7    3000  2000  default
# status
# default    1.0
# Name: proportion, dtype: float64
#
# 2000
#    assets  debt   status
# 1    2000  1000  default
# 2       0  1000  default
# 3    5000  1000       ok
# 4    5000  1000       ok
# 5    4000  1000       ok
# 6    9000   500       ok
# 7    3000  2000  default
# status
# ok         0.571429
# default    0.428571
# Name: proportion, dtype: float64
#    assets  debt   status
# 0    8000  3000  default
# status
# default    1.0
# Name: proportion, dtype: float64
#
# #####################

# %% [markdown]
# 6.5 Decision trees parameter tuning

# %%
depths = [1, 2, 3, 4, 5, 6, 10, 15, 20, None]

for depth in depths: 
    dt = DecisionTreeClassifier(max_depth=depth)
    dt.fit(X_train, y_train)
    
    y_pred = dt.predict_proba(X_val)[:, 1]
    auc = roc_auc_score(y_val, y_pred)
    
    print('%4s -> %.3f' % (depth, auc))
# Out:
#    1 -> 0.606
#    2 -> 0.669
#    3 -> 0.739
#    4 -> 0.761
#    5 -> 0.767
#    6 -> 0.757
#   10 -> 0.684
#   15 -> 0.662
#   20 -> 0.662
# None -> 0.653

# %%
scores = []

for depth in [4, 5, 6]:
    for s in [1, 5, 10, 15, 20, 500, 100, 200]:
        dt = DecisionTreeClassifier(max_depth=depth, min_samples_leaf=s)
        dt.fit(X_train, y_train)

        y_pred = dt.predict_proba(X_val)[:, 1]
        auc = roc_auc_score(y_val, y_pred)
        
        scores.append((depth, s, auc))

# %%
columns = ['max_depth', 'min_samples_leaf', 'auc']
df_scores = pd.DataFrame(scores, columns=columns)

# %%
df_scores.head()
# Out:
#    max_depth  min_samples_leaf       auc
# 0          4                 1  0.761283
# 1          4                 5  0.761283
# 2          4                10  0.761283
# 3          4                15  0.763726
# 4          4                20  0.760910

# %%
df_scores_pivot = df_scores.pivot(index='min_samples_leaf', columns=['max_depth'], values=['auc'])
df_scores_pivot.round(3)
# Out:
#                     auc
# max_depth             4      5      6
# min_samples_leaf
# 1                 0.761  0.767  0.757
# 5                 0.761  0.768  0.760
# 10                0.761  0.762  0.778
# 15                0.764  0.772  0.785
# 20                0.761  0.774  0.774
# 100               0.756  0.763  0.776
# 200               0.747  0.759  0.768
# 500               0.680  0.680  0.680

# %%
sns.heatmap(df_scores_pivot, annot=True, fmt=".3f")
# Out:
# <Axes: xlabel='None-max_depth', ylabel='min_samples_leaf'>

# %%
dt = DecisionTreeClassifier(max_depth=6, min_samples_leaf=15)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=15)

# %%
print(export_text(dt, feature_names=list(dv.get_feature_names_out())))
# Out:
# |--- records=no <= 0.50
# |   |--- seniority <= 6.50
# |   |   |--- amount <= 862.50
# |   |   |   |--- price <= 925.00
# |   |   |   |   |--- amount <= 525.00
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- amount >  525.00
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- price >  925.00
# |   |   |   |   |--- price <= 1382.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- price >  1382.00
# |   |   |   |   |   |--- class: 0
# |   |   |--- amount >  862.50
# |   |   |   |--- assets <= 8250.00
# |   |   |   |   |--- job=fixed <= 0.50
# |   |   |   |   |   |--- assets <= 3425.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- assets >  3425.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- job=fixed >  0.50
# |   |   |   |   |   |--- age <= 31.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- age >  31.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- assets >  8250.00
# |   |   |   |   |--- income <= 132.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- income >  132.50
# |   |   |   |   |   |--- class: 0
# |   |--- seniority >  6.50
# |   |   |--- income <= 103.50
# |   |   |   |--- assets <= 4500.00
# |   |   |   |   |--- seniority <= 12.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- seniority >  12.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- assets >  4500.00
# |   |   |   |   |--- class: 0
# |   |   |--- income >  103.50
# |   |   |   |--- time <= 33.00
# |   |   |   |   |--- class: 0
# |   |   |   |--- time >  33.00
# |   |   |   |   |--- seniority <= 11.50
# |   |   |   |   |   |--- assets <= 4750.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- assets >  4750.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- seniority >  11.50
# |   |   |   |   |   |--- assets <= 7250.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- assets >  7250.00
# |   |   |   |   |   |   |--- class: 0
# |--- records=no >  0.50
# |   |--- job=partime <= 0.50
# |   |   |--- income <= 74.50
# |   |   |   |--- assets <= 4250.00
# |   |   |   |   |--- income <= 20.00
# |   |   |   |   |   |--- seniority <= 1.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- seniority >  1.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- income >  20.00
# |   |   |   |   |   |--- expenses <= 71.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- expenses >  71.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- assets >  4250.00
# |   |   |   |   |--- debt <= 1600.00
# |   |   |   |   |   |--- seniority <= 2.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- seniority >  2.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- debt >  1600.00
# |   |   |   |   |   |--- class: 1
# |   |   |--- income >  74.50
# |   |   |   |--- seniority <= 5.50
# |   |   |   |   |--- amount <= 1330.00
# |   |   |   |   |   |--- assets <= 3326.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- assets >  3326.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- amount >  1330.00
# |   |   |   |   |   |--- assets <= 3750.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- assets >  3750.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- seniority >  5.50
# |   |   |   |   |--- income <= 114.50
# |   |   |   |   |   |--- expenses <= 84.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- expenses >  84.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- income >  114.50
# |   |   |   |   |   |--- amount <= 1188.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- amount >  1188.50
# |   |   |   |   |   |   |--- class: 0
# |   |--- job=partime >  0.50
# |   |   |--- assets <= 7250.00
# |   |   |   |--- time <= 27.00
# |   |   |   |   |--- price <= 909.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- price >  909.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- time >  27.00
# |   |   |   |   |--- age <= 34.50
# |   |   |   |   |   |--- price <= 1049.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- price >  1049.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- age >  34.50
# |   |   |   |   |   |--- assets <= 2750.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- assets >  2750.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- assets >  7250.00
# |   |   |   |--- class: 0

# %% [markdown]
# 6.6 Ensembles and random forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=10)

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
y_pred = rf.predict_proba(X_val)[:,1]

# %%
roc_auc_score(y_val, y_pred)
# Out:
# np.float64(0.7928513477513259)

# %%
from tqdm.auto import tqdm

scores = []
for n in tqdm(range(10,201, 10)):
    rf = RandomForestClassifier(n_estimators=n)
    rf.fit(X_train, y_train)
    y_pred = rf.predict_proba(X_val)[:,1]
    auc = roc_auc_score(y_val, y_pred)
    scores.append((n, auc))
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
scores_df = pd.DataFrame(scores, columns = ['n_estimators', 'auc_scores'])
scores_df
# Out:
#     n_estimators  auc_scores
# 0             10    0.795609
# 1             20    0.810155
# 2             30    0.808251
# 3             40    0.804945
# 4             50    0.815889
# 5             60    0.814400
# 6             70    0.815041
# 7             80    0.814602
# 8             90    0.820917
# 9            100    0.819358
# 10           110    0.817027
# 11           120    0.820079
# 12           130    0.818326
# 13           140    0.822585
# 14           150    0.819331
# 15           160    0.821099
# 16           170    0.819800
# 17           180    0.821686
# 18           190    0.822047
# 19           200    0.818187

# %%
plt.plot(scores_df.n_estimators, scores_df.auc_scores)

# %%
scores = []
for d in tqdm([5,10,15]):
    for n in range(10,201, 10):
        rf = RandomForestClassifier(n_estimators=n, max_depth=d, random_state=1)
        rf.fit(X_train, y_train)
        y_pred = rf.predict_proba(X_val)[:,1]
        auc = roc_auc_score(y_val, y_pred)
        scores.append((n, d, auc))


scores_df = pd.DataFrame(scores, columns = ['n_estimators', 'depth', 'auc_scores'])
scores_df
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#     n_estimators  depth  auc_scores
# 0             10      5    0.787699
# 1             20      5    0.797731
# 2             30      5    0.800305
# 3             40      5    0.799708
# 4             50      5    0.799878
# 5             60      5    0.801167
# 6             70      5    0.802203
# 7             80      5    0.803238
# 8             90      5    0.803447
# 9            100      5    0.804385
# 10           110      5    0.806523
# 11           120      5    0.806517
# 12           130      5    0.807994
# 13           140      5    0.806850
# 14           150      5    0.807255
# 15           160      5    0.807068
# 16           170      5    0.806819
# 17           180      5    0.807177
# 18           190      5    0.806995
# 19           200      5    0.807279
# 20            10     10    0.795818
# 21            20     10    0.810597
# 22            30     10    0.813510
# 23            40     10    0.819013
# 24            50     10    0.818160
# 25            60     10    0.819086
# 26            70     10    0.820503
# 27            80     10    0.821132
# 28            90     10    0.821314
# 29           100     10    0.822616
# 30           110     10    0.824045
# 31           120     10    0.824305
# 32           130     10    0.825522
# 33           140     10    0.824886
# 34           150     10    0.824971
# 35           160     10    0.825449
# 36           170     10    0.824983
# 37           180     10    0.825050
# 38           190     10    0.824589
# 39           200     10    0.824529
# 40            10     15    0.795897
# 41            20     15    0.812450
# 42            30     15    0.812141
# 43            40     15    0.813891
# 44            50     15    0.814100
# 45            60     15    0.814481
# 46            70     15    0.813897
# 47            80     15    0.815023
# 48            90     15    0.815238
# 49           100     15    0.815765
# 50           110     15    0.816277
# 51           120     15    0.817905
# 52           130     15    0.818132
# 53           140     15    0.818087
# 54           150     15    0.817981
# 55           160     15    0.818717
# 56           170     15    0.818653
# 57           180     15    0.819307
# 58           190     15    0.819122
# 59           200     15    0.819416

# %%
for d in [5,10,15]:
    df_scores_depth = scores_df[scores_df.depth == d]
    plt.plot(df_scores_depth.n_estimators, df_scores_depth.auc_scores, label = 'max depth = %d' % d)

plt.legend()

# %%
max_depth = 10

# %%
scores = []
for s in tqdm([1, 3, 5, 10, 50]):
    for n in range(10,201, 10):
        rf = RandomForestClassifier(n_estimators=n, 
                                    max_depth=max_depth,
                                    min_samples_leaf=s, 
                                    random_state=1)
        rf.fit(X_train, y_train)
        y_pred = rf.predict_proba(X_val)[:,1]
        auc = roc_auc_score(y_val, y_pred)
        scores.append((n, s, auc))


scores_df = pd.DataFrame(scores, columns = ['n_estimators', 'min_samples', 'auc_scores'])
scores_df
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#     n_estimators  min_samples  auc_scores
# 0             10            1    0.795818
# 1             20            1    0.810597
# 2             30            1    0.813510
# 3             40            1    0.819013
# 4             50            1    0.818160
# ..           ...          ...         ...
# 95           160           50    0.806020
# 96           170           50    0.805191
# 97           180           50    0.805094
# 98           190           50    0.805427
# 99           200           50    0.805439
#
# [100 rows x 3 columns]

# %%
for s in [1, 3, 5, 10, 50]:
    df_scores_samples = scores_df[scores_df.min_samples == s]
    plt.plot(df_scores_samples.n_estimators, df_scores_samples.auc_scores, label = 'min samples = %s' % s)

plt.legend()

# %%
min_samples = 3

# %%
rf = RandomForestClassifier(n_estimators=100, 
                            max_depth=max_depth,
                            min_samples_leaf=min_samples, 
                            random_state=1)
rf.fit(X_train, y_train)
y_pred = rf.predict_proba(X_val)[:,1]
auc = roc_auc_score(y_val, y_pred)
auc
# Out:
# np.float64(0.8241172410452641)

# %% [markdown]
# Gradient Boosting

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-2.1.4-py3-none-macosx_12_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /Users/denismasterov/Documents/python/ml_zoomcamp/ml_zoomcamp/.venv/lib/python3.9/site-packages (from xgboost) (2.0.2)
# Requirement already satisfied: scipy in /Users/denismasterov/Documents/python/ml_zoomcamp/ml_zoomcamp/.venv/lib/python3.9/site-packages (from xgboost) (1.13.1)
# Downloading xgboost-2.1.4-py3-none-macosx_12_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 7.8 MB/s  0:00:0036m-:--:--
# Installing collected packages: xgboost
# Successfully installed xgboost-2.1.4

# %%
# !pip install libomp
# Out:
# ERROR: Could not find a version that satisfies the requirement libomp (from versions: none)
# ERROR: No matching distribution found for libomp

# %%
import xgboost as xgb

# %%
features = list(dv.get_feature_names_out())
dtrain = xgb.DMatrix(X_train, label=y_train, feature_names=features)
dval = xgb.DMatrix(X_val, label=y_val, feature_names=features)

# %%
xgb_params = {
    'eta': 0.3, 
    'max_depth': 6,
    'min_child_weight': 1,
    
    'objective': 'binary:logistic',
    'nthread': 8,
    
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, num_boost_round=10)

# %%
y_pred = model.predict(dval)

# %%
roc_auc_score(y_val, y_pred)
# Out:
# np.float64(0.8072491584122448)

# %%
watchlist = [(dtrain, 'train'), (dval, 'val')]

# %%
# %%capture output

xgb_params = {
    'eta': 0.3, 
    'max_depth': 6,
    'min_child_weight': 1,
    
    'objective': 'binary:logistic',
    'eval_metric': 'auc',

    'nthread': 8,
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, num_boost_round=200,
                  verbose_eval=5,
                  evals=watchlist)

# %%
s = output.stdout

# %%
print(s[:200])
# Out:
# [0]	train-auc:0.86730	val-auc:0.77938
# [5]	train-auc:0.93086	val-auc:0.80858
# [10]	train-auc:0.95447	val-auc:0.80851
# [15]	train-auc:0.96554	val-auc:0.81334
# [20]	train-auc:0.97464	val-auc:0.81729
# [25]	tr

# %%
line = s.split('\n')[0]

num_iter, train_auc, val_auc = line.split('\t')

print(int(num_iter.strip('[]')), train_auc.split(':')[1], val_auc.split(':')[1])
# Out:
# 0 0.86730 0.77938

# %%
def parse_xgb_output(output):
    results = []

    for line in output.stdout.strip().split('\n'):
        it_line, train_line, val_line = line.split('\t')

        it = int(it_line.strip('[]'))
        train = float(train_line.split(':')[1])
        val = float(val_line.split(':')[1])

        results.append((it, train, val))
    
    columns = ['num_iter', 'train_auc', 'val_auc']
    df_results = pd.DataFrame(results, columns=columns)
    return df_results

# %%
df_score = parse_xgb_output(output)

# %%
plt.plot(df_score.num_iter, df_score.train_auc, label='train')
plt.plot(df_score.num_iter, df_score.val_auc, label='val')
plt.legend()

# %%
plt.plot(df_score.num_iter, df_score.val_auc, label='val')
plt.legend()

# %% [markdown]
# XGBoost parameter tuning

# %%
scores = {}

# %%
# %%capture output

xgb_params = {
    'eta': 0.1, 
    'max_depth': 6,
    'min_child_weight': 1,
    
    'objective': 'binary:logistic',
    'eval_metric': 'auc',

    'nthread': 8,
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, num_boost_round=200,
                  verbose_eval=5,
                  evals=watchlist)
# Out:
# [0]	train-auc:0.86730	val-auc:0.77938
# [5]	train-auc:0.90325	val-auc:0.79290
# [10]	train-auc:0.91874	val-auc:0.80510
# [15]	train-auc:0.93126	val-auc:0.81380
# [20]	train-auc:0.93873	val-auc:0.81804
# [25]	train-auc:0.94638	val-auc:0.82065
# [30]	train-auc:0.95338	val-auc:0.82063
# [35]	train-auc:0.95874	val-auc:0.82404
# [40]	train-auc:0.96325	val-auc:0.82644
# [45]	train-auc:0.96694	val-auc:0.82602
# [50]	train-auc:0.97195	val-auc:0.82549
# [55]	train-auc:0.97475	val-auc:0.82648
# [60]	train-auc:0.97708	val-auc:0.82781
# [65]	train-auc:0.97937	val-auc:0.82775
# [70]	train-auc:0.98214	val-auc:0.82681
# [75]	train-auc:0.98315	val-auc:0.82728
# [80]	train-auc:0.98517	val-auc:0.82560
# [85]	train-auc:0.98721	val-auc:0.82503
# [90]	train-auc:0.98840	val-auc:0.82443
# [95]	train-auc:0.98972	val-auc:0.82389
# [100]	train-auc:0.99061	val-auc:0.82456
# [105]	train-auc:0.99157	val-auc:0.82359
# [110]	train-auc:0.99224	val-auc:0.82274
# [115]	train-auc:0.99288	val-auc:0.82147
# [120]	train-auc:0.99378	val-auc:0.82154
# [125]	train-auc:0.99481	val-auc:0.82195
# [130]	train-auc:0.99541	val-auc:0.82252
# [135]	train-auc:0.99564	val-auc:0.82190
# [140]	train-auc:0.99630	val-auc:0.82219
# [145]	train-auc:0.99673	val-auc:0.82177
# [150]	train-auc:0.99711	val-auc:0.82136
# [155]	train-auc:0.99750	val-auc:0.82154
# [160]	train-auc:0.99774	val-auc:0.82102
# [165]	train-auc:0.99821	val-auc:0.82060
# [170]	train-auc:0.99838	val-auc:0.82060
# [175]	train-auc:0.99861	val-auc:0.82012
# [180]	train-auc:0.99882	val-auc:0.82053
# [185]	train-auc:0.99898	val-auc:0.82028
# [190]	train-auc:0.99904	val-auc:0.81973
# [195]	train-auc:0.99920	val-auc:0.81909
# [199]	train-auc:0.99927	val-auc:0.81864

# %%
scores.keys()
# Out:
# dict_keys(['eta=0.01', 'eta=0.3', 'eta=1', 'eta=0.05', 'eta=0.1'])

# %%
key = 'eta=%s' % (xgb_params['eta'])
scores[key] = parse_xgb_output(output)
key
# Out:
# 'eta=0.1'

# %%
for key, df_score in scores.items():
    plt.plot(df_score.num_iter, df_score.val_auc, label=key)

plt.ylim(0.8, 0.84)
plt.legend()

# %%
scores = {}

# %%
# %%capture output

xgb_params = {
    'eta': 0.1, 
    'max_depth': 10,
    'min_child_weight': 1,
    
    'objective': 'binary:logistic',
    'eval_metric': 'auc',

    'nthread': 8,
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, num_boost_round=200,
                  verbose_eval=5,
                  evals=watchlist)

# %%
key = 'max_depth=%s' % (xgb_params['max_depth'])
scores[key] = parse_xgb_output(output)
key
# Out:
# 'max_depth=10'

# %%
scores.keys()
# Out:
# dict_keys(['max_depth=6', 'max_depth=8', 'max_depth=4', 'max_depth=10'])

# %%
del scores['max_depth=10']

# %%
for max_depth, df_score in scores.items():
    plt.plot(df_score.num_iter, df_score.val_auc, label=max_depth)

plt.ylim(0.8, 0.84)
plt.legend()

# %%
scores = {}

# %%
# %%capture output

xgb_params = {
    'eta': 0.1, 
    'max_depth': 3,
    'min_child_weight': 30,
    
    'objective': 'binary:logistic',
    'eval_metric': 'auc',

    'nthread': 8,
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, num_boost_round=200,
                  verbose_eval=5,
                  evals=watchlist)

# %%
key = 'min_child_weight=%s' % (xgb_params['min_child_weight'])
scores[key] = parse_xgb_output(output)
key
# Out:
# 'min_child_weight=30'

# %%
scores.keys()
# Out:
# dict_keys(['min_child_weight=1', 'min_child_weight=10', 'min_child_weight=30'])

# %%
for min_child_weight, df_score in scores.items():
    plt.plot(df_score.num_iter, df_score.val_auc, label=min_child_weight)

plt.ylim(0.82, 0.84)
plt.legend()

# %%
xgb_params = {
    'eta': 0.1, 
    'max_depth': 3,
    'min_child_weight': 30,
    
    'objective': 'binary:logistic',
    'eval_metric': 'auc',

    'nthread': 8,
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, num_boost_round=175,
                  verbose_eval=5,
                  evals=watchlist)
# Out:
# [0]	train-auc:0.76455	val-auc:0.73369
# [5]	train-auc:0.82689	val-auc:0.77398
# [10]	train-auc:0.84376	val-auc:0.79435
# [15]	train-auc:0.85530	val-auc:0.80579
# [20]	train-auc:0.86049	val-auc:0.81030
# [25]	train-auc:0.86624	val-auc:0.81448
# [30]	train-auc:0.87145	val-auc:0.81905
# [35]	train-auc:0.87507	val-auc:0.82076
# [40]	train-auc:0.87690	val-auc:0.82313
# [45]	train-auc:0.87887	val-auc:0.82504
# [50]	train-auc:0.88031	val-auc:0.82576
# [55]	train-auc:0.88207	val-auc:0.82798
# [60]	train-auc:0.88345	val-auc:0.82945
# [65]	train-auc:0.88471	val-auc:0.83014
# [70]	train-auc:0.88596	val-auc:0.83073
# [75]	train-auc:0.88735	val-auc:0.83165
# [80]	train-auc:0.88832	val-auc:0.83254
# [85]	train-auc:0.88942	val-auc:0.83324
# [90]	train-auc:0.89024	val-auc:0.83380
# [95]	train-auc:0.89118	val-auc:0.83437
# [100]	train-auc:0.89204	val-auc:0.83463
# [105]	train-auc:0.89285	val-auc:0.83504
# [110]	train-auc:0.89363	val-auc:0.83575
# [115]	train-auc:0.89419	val-auc:0.83591
# [120]	train-auc:0.89519	val-auc:0.83618
# [125]	train-auc:0.89570	val-auc:0.83624
# [130]	train-auc:0.89629	val-auc:0.83672
# [135]	train-auc:0.89695	val-auc:0.83687
# [140]	train-auc:0.89760	val-auc:0.83731
# [145]	train-auc:0.89821	val-auc:0.83718
# [150]	train-auc:0.89866	val-auc:0.83728
# [155]	train-auc:0.89918	val-auc:0.83743
# [160]	train-auc:0.89970	val-auc:0.83743
# [165]	train-auc:0.90008	val-auc:0.83715
# [170]	train-auc:0.90050	val-auc:0.83681
# [174]	train-auc:0.90094	val-auc:0.83663

# %% [markdown]
# Selecting the final model

# %%
dt = DecisionTreeClassifier(max_depth=6, min_samples_leaf=15)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=15)

# %%
y_pred = dt.predict_proba(X_val)[:, 1]
roc_auc_score(y_val, y_pred)
# Out:
# np.float64(0.7850802838390931)

# %%
rf = RandomForestClassifier(n_estimators=200,
                            max_depth=10,
                            min_samples_leaf=3,
                            random_state=1)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=3, n_estimators=200,
#                        random_state=1)

# %%
y_pred = rf.predict_proba(X_val)[:, 1]
roc_auc_score(y_val, y_pred)
# Out:
# np.float64(0.8249709379767989)

# %%
xgb_params = {
    'eta': 0.1, 
    'max_depth': 3,
    'min_child_weight': 1,

    'objective': 'binary:logistic',
    'eval_metric': 'auc',

    'nthread': 8,
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, num_boost_round=175)

# %%
y_pred = model.predict(dval)
roc_auc_score(y_val, y_pred)
# Out:
# np.float64(0.8309347073212081)

# %%
df_full_train = df_full_train.reset_index(drop=True)

# %%
y_full_train = (df_full_train.status == 'default').astype(int).values

# %%
del df_full_train['status']

# %%
dicts_full_train = df_full_train.to_dict(orient='records')

dv = DictVectorizer(sparse=False)
X_full_train = dv.fit_transform(dicts_full_train)

dicts_test = df_test.to_dict(orient='records')
X_test = dv.transform(dicts_test)

# %%
len(dv.get_feature_names_out())
# Out:
# 29

# %%
features = list(dv.get_feature_names_out())
dfulltrain = xgb.DMatrix(X_full_train, 
                            label=y_full_train,
                            feature_names=features)

dtest = xgb.DMatrix(X_test, feature_names=features)

# %%
xgb_params = {
    'eta': 0.1, 
    'max_depth': 3,
    'min_child_weight': 1,

    'objective': 'binary:logistic',
    'eval_metric': 'auc',

    'nthread': 8,
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dfulltrain, num_boost_round=175)

# %%
y_pred = model.predict(dtest)

# %%
roc_auc_score(y_test, y_pred)
# Out:
# np.float64(0.8289367577342261)
